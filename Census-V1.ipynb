# %% [markdown]
# # ML Project: Classification
#
# ## Predict what has the most influence over income
#
# - Education vs Salary
# - Sex vs Salary
# - Race vs Salary
# - Native-Country vs Salary
#
# $50K/yr based on census data
#
# Authors:
# `Andrea Murphy` and `Josh Quigley`

# %% [markdown]
# ## Setup

# %%
# %matplotlib inline
import random

import pandas as pd
from pandas import Series,DataFrame
import numpy as np

from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier

import numpy as np
import matplotlib.pyplot as plt

# %%
import pylab as plot
params = { 
    "axes.labelsize": "large",
    "xtick.labelsize" : "x-large",
    "legend.fontsize": 20,
    "figure.dpi": 150,
    "figure.figsize" : [25, 7]
}
plot.rcParams.update(params)

# %%
data = pd.read_csv('data/adult.data.txt')
test_data = pd.read_csv('data/adult.test.txt') 

data.columns = ["age", "workclass", "fnlwgt", "education", "education-num", "marital-status", "occupation", "relationship", "race",
                           "sex", "capital-gain", "capital-loss", "hours-per-week", "native-country", "salary"]
data.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         marital-status          occupation    relationship    race      sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40            Cuba   <=50K
# 4             0             0              40   United-States   <=50K

# %%
data.tail()
# Out:
#        age      workclass  fnlwgt    education  education-num  \
# 32555   27        Private  257302   Assoc-acdm             12
# 32556   40        Private  154374      HS-grad              9
# 32557   58        Private  151910      HS-grad              9
# 32558   22        Private  201490      HS-grad              9
# 32559   52   Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation relationship    race      sex  \
# 32555   Married-civ-spouse        Tech-support         Wife   White   Female
# 32556   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32557              Widowed        Adm-clerical    Unmarried   White   Female
# 32558        Never-married        Adm-clerical    Own-child   White     Male
# 32559   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital-gain  capital-loss  hours-per-week  native-country  salary
# 32555             0             0              38   United-States   <=50K
# 32556             0             0              40   United-States    >50K
# 32557             0             0              40   United-States   <=50K
# 32558             0             0              20   United-States   <=50K
# 32559         15024             0              40   United-States    >50K

# %%
type(data.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %% [markdown]
# ## Education vs Salary

# %%
# drop columns won't be useful in analysis and prediction
data_education = data.drop(['fnlwgt', 'education-num'], axis=1)

# %%
data_education.head()
# Out:
#    age          workclass   education       marital-status  \
# 0   50   Self-emp-not-inc   Bachelors   Married-civ-spouse
# 1   38            Private     HS-grad             Divorced
# 2   53            Private        11th   Married-civ-spouse
# 3   28            Private   Bachelors   Married-civ-spouse
# 4   37            Private     Masters   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital-gain  \
# 0     Exec-managerial         Husband   White     Male             0
# 1   Handlers-cleaners   Not-in-family   White     Male             0
# 2   Handlers-cleaners         Husband   Black     Male             0
# 3      Prof-specialty            Wife   Black   Female             0
# 4     Exec-managerial            Wife   White   Female             0
#
#    capital-loss  hours-per-week  native-country  salary
# 0             0              13   United-States   <=50K
# 1             0              40   United-States   <=50K
# 2             0              40   United-States   <=50K
# 3             0              40            Cuba   <=50K
# 4             0              40   United-States   <=50K

# %%
data_education.shape
# Out:
# (32560, 13)

# %% [markdown]
# ## Decreasing the sample size `n=100` for ease of use

# %%
data_education.sample(n=100, random_state=10)
# Out:
#        age          workclass      education       marital-status  \
# 11358   41            Private      Bachelors   Married-civ-spouse
# 10859   38            Private   Some-college   Married-civ-spouse
# 30948   24            Private        HS-grad            Separated
# 29811   35       Self-emp-inc      Bachelors            Separated
# 18408   69                  ?      Bachelors   Married-civ-spouse
# 2879    31            Private        HS-grad        Never-married
# 21575   35            Private        HS-grad   Married-civ-spouse
# 26396   25            Private        HS-grad            Separated
# 28644   56            Private      Assoc-voc   Married-civ-spouse
# 15694   22        Without-pay        HS-grad        Never-married
# 23007   59   Self-emp-not-inc        Masters   Married-civ-spouse
# 2647    32            Private   Some-college        Never-married
# 19108   18            Private           10th        Never-married
# 545     58            Private           10th   Married-civ-spouse
# 14794   59            Private        HS-grad   Married-civ-spouse
# 29400   60            Private        5th-6th   Married-civ-spouse
# 12808   44            Private   Some-college   Married-civ-spouse
# 22724   23            Private        HS-grad        Never-married
# 17729   33          State-gov        HS-grad   Married-civ-spouse
# 19705   22                  ?           12th        Never-married
# 32412   45            Private        5th-6th   Married-civ-spouse
# 27828   36          Local-gov      Bachelors             Divorced
# 31952   37            Private      Bachelors   Married-civ-spouse
# 3407    29            Private     Assoc-acdm   Married-civ-spouse
# 21190   45            Private      Doctorate            Separated
# 29563   38            Private   Some-college   Married-civ-spouse
# 22977   35            Private        Masters            Separated
# 16345   22                  ?        7th-8th        Never-married
# 13532   44            Private        Masters   Married-civ-spouse
# 19306   29            Private           11th        Never-married
# ...    ...                ...            ...                  ...
# 8939    27                  ?   Some-college             Divorced
# 3760    57            Private    Prof-school        Never-married
# 3066    41          Local-gov      Bachelors              Widowed
# 9539    19            Private        HS-grad        Never-married
# 23920   29            Private        5th-6th   Married-civ-spouse
# 21990   35            Private        HS-grad   Married-civ-spouse
# 30184   43            Private           11th   Married-civ-spouse
# 513     28            Private        HS-grad             Divorced
# 20761   31          State-gov   Some-college        Never-married
# 31391   64            Private        HS-grad        Never-married
# 31544   33        Federal-gov      Bachelors        Never-married
# 29538   49            Private        HS-grad   Married-civ-spouse
# 14155   21            Private   Some-college        Never-married
# 14696   24            Private   Some-college        Never-married
# 13397   50            Private        HS-grad   Married-civ-spouse
# 18502   49            Private           11th             Divorced
# 997     40            Private   Some-college   Married-civ-spouse
# 18462   74            Private    Prof-school   Married-civ-spouse
# 24508   37            Private        HS-grad   Married-civ-spouse
# 19204   28            Private        HS-grad        Never-married
# 12503   28            Private   Some-college   Married-civ-spouse
# 21561   44        Federal-gov      Bachelors   Married-civ-spouse
# 8723    52       Self-emp-inc           10th   Married-civ-spouse
# 1058    45            Private        HS-grad   Married-civ-spouse
# 27681   24            Private        HS-grad        Never-married
# 30772   38        Federal-gov      Bachelors   Married-civ-spouse
# 19781   40          State-gov   Some-college             Divorced
# 21634   27   Self-emp-not-inc      Assoc-voc        Never-married
# 11391   42            Private     Assoc-acdm   Married-civ-spouse
# 22201   20            Private        HS-grad        Never-married
#
#                occupation     relationship    race      sex  capital-gain  \
# 11358               Sales          Husband   White     Male             0
# 10859               Sales          Husband   White     Male             0
# 30948   Machine-op-inspct        Unmarried   Other   Female             0
# 29811      Prof-specialty    Not-in-family   White   Female             0
# 18408                   ?          Husband   White     Male         10605
# 2879    Handlers-cleaners   Other-relative   White     Male             0
# 21575     Exec-managerial          Husband   White     Male             0
# 26396     Exec-managerial        Unmarried   White   Female             0
# 545               0               8   United-States   <=50K
# 14794          1485              45   United-States    >50K
# 29400             0              40               ?    >50K
# 12808             0              40   United-States    >50K
# 22724             0              16   United-States   <=50K
# 17729             0              40   United-States   <=50K
# 19705             0              48   United-States   <=50K
# 32412             0              40               ?   <=50K
# 27828             0              40   United-States   <=50K
# 31952          1848              40   United-States    >50K
# 3407              0              50   United-States    >50K
# 21190             0              40   United-States    >50K
# 29563             0              60   United-States   <=50K
# 22977             0              40   United-States    >50K
# 16345             0              40          Mexico   <=50K
# 13532             0              45   United-States   <=50K
# 19306             0              48   United-States   <=50K
# ...             ...             ...             ...     ...
# 8939              0              30   United-States   <=50K
# 3760              0              40   United-States   <=50K
# 3066              0              40   United-States   <=50K
# 9539              0              30   United-States   <=50K
# 23920             0              40          Mexico   <=50K
# 21990             0              40          Mexico   <=50K
# 30184             0              40   United-States   <=50K
# 513               0              45   United-States   <=50K
# 20761             0              40   United-States   <=50K
# 31391             0               3   United-States   <=50K
# 31544             0              40   United-States   <=50K
# 29538             0              40   United-States   <=50K
# 14155             0              65   United-States   <=50K
# 14696             0              42   United-States   <=50K
# 13397             0              40   United-States   <=50K
# 18502             0              38   United-States   <=50K
# 997               0              40   United-States   <=50K
# 18462             0              50   United-States    >50K
# 24508          1902              50   United-States   <=50K
# 19204             0              40   United-States   <=50K
# 12503             0              35   United-States    >50K
# 21561             0              48   United-States   <=50K
# 8723              0              45   United-States   <=50K
# 1058              0              47   United-States    >50K
# 27681             0              30   United-States   <=50K
# 30772             0              40               ?    >50K
# 19781             0              35   United-States   <=50K
# 21634             0              40   United-States   <=50K
# 11391             0              40   United-States   <=50K
# 22201             0              40   United-States   <=50K
#
# [100 rows x 13 columns]

# %% [markdown]
# ## Sex vs Salary

# %%
# drop columns won't be useful in analysis and prediction
data_sex = data.drop(['fnlwgt', 'education-num', 'education', 'race'], axis=1)

# %%
data_sex.head()
# Out:
#    age          workclass       marital-status          occupation  \
# 0   50   Self-emp-not-inc   Married-civ-spouse     Exec-managerial
# 1   38            Private             Divorced   Handlers-cleaners
# 2   53            Private   Married-civ-spouse   Handlers-cleaners
# 3   28            Private   Married-civ-spouse      Prof-specialty
# 4   37            Private   Married-civ-spouse     Exec-managerial
#
#      relationship      sex  capital-gain  capital-loss  hours-per-week  \
# 0         Husband     Male             0             0              13
# 1   Not-in-family     Male             0             0              40
# 2         Husband     Male             0             0              40
# 3            Wife   Female             0             0              40
# 4            Wife   Female             0             0              40
#
#    native-country  salary
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3            Cuba   <=50K
# 4   United-States   <=50K

# %%
data_sex.shape
# Out:
# (32560, 11)

# %% [markdown]
# ## Decreasing the sample size `n=100` for ease of use

# %%
data_sex.sample(n=100, random_state=10)
# Out:
#        age          workclass       marital-status          occupation  \
# 11358   41            Private   Married-civ-spouse               Sales
# 10859   38            Private   Married-civ-spouse               Sales
# 30948   24            Private            Separated   Machine-op-inspct
# 29811   35       Self-emp-inc            Separated      Prof-specialty
# 18408   69                  ?   Married-civ-spouse                   ?
# 2879    31            Private        Never-married   Handlers-cleaners
# 21575   35            Private   Married-civ-spouse     Exec-managerial
# 26396   25            Private            Separated     Exec-managerial
# 28644   56            Private   Married-civ-spouse     Exec-managerial
# 15694   22        Without-pay        Never-married   Handlers-cleaners
# 23007   59   Self-emp-not-inc   Married-civ-spouse        Craft-repair
# 2647    32            Private        Never-married        Adm-clerical
# 19108   18            Private        Never-married       Other-service
# 545     58            Private   Married-civ-spouse       Other-service
# 14794   59            Private   Married-civ-spouse        Craft-repair
# 29400   60            Private   Married-civ-spouse               Sales
# 12808   44            Private   Married-civ-spouse       Other-service
# 22724   23            Private        Never-married        Adm-clerical
# 17729   33          State-gov   Married-civ-spouse        Tech-support
# 19705   22                  ?        Never-married                   ?
# 32412   45            Private   Married-civ-spouse   Machine-op-inspct
# 27828   36          Local-gov             Divorced      Prof-specialty
# 31952   37            Private   Married-civ-spouse     Exec-managerial
# 3407    29            Private   Married-civ-spouse               Sales
# 21190   45            Private            Separated     Exec-managerial
# 29563   38            Private   Married-civ-spouse               Sales
# 22977   35            Private            Separated      Prof-specialty
# 16345   22                  ?        Never-married                   ?
# 13532   44            Private   Married-civ-spouse      Prof-specialty
# 19306   29            Private        Never-married   Machine-op-inspct
# ...    ...                ...                  ...                 ...
# 8939    27                  ?             Divorced                   ?
# 3760    57            Private        Never-married      Prof-specialty
# 3066    41          Local-gov              Widowed        Adm-clerical
# 9539    19            Private        Never-married       Other-service
# 23920   29            Private   Married-civ-spouse     Farming-fishing
# 21990   35            Private   Married-civ-spouse   Handlers-cleaners
# 30184   43            Private   Married-civ-spouse   Handlers-cleaners
# 513     28            Private             Divorced        Craft-repair
# 20761   31          State-gov        Never-married        Craft-repair
# 31391   64            Private        Never-married     Exec-managerial
# 31544   33        Federal-gov        Never-married      Prof-specialty
# 29538   49            Private   Married-civ-spouse    Transport-moving
# 14155   21            Private        Never-married        Adm-clerical
# 14696   24            Private        Never-married     Exec-managerial
# 13397   50            Private   Married-civ-spouse        Craft-repair
# 18502   49            Private             Divorced     Exec-managerial
# 997     40            Private   Married-civ-spouse   Machine-op-inspct
# 18462   74            Private   Married-civ-spouse      Prof-specialty
# 24508   37            Private   Married-civ-spouse        Craft-repair
# 19204   28            Private        Never-married    Transport-moving
# 12503   28            Private   Married-civ-spouse       Other-service
# 21561   44        Federal-gov   Married-civ-spouse     Exec-managerial
# 8723    52       Self-emp-inc   Married-civ-spouse               Sales
# 1058    45            Private   Married-civ-spouse        Craft-repair
# 27681   24            Private        Never-married       Other-service
# 30772   38        Federal-gov   Married-civ-spouse      Prof-specialty
# 19781   40          State-gov             Divorced        Adm-clerical
# 21634   27   Self-emp-not-inc        Never-married        Craft-repair
# 11391   42            Private   Married-civ-spouse        Tech-support
# 22201   20            Private        Never-married        Adm-clerical
#
#           relationship      sex  capital-gain  capital-loss  hours-per-week  \
# 11358          Husband     Male             0             0              50
# 10859          Husband     Male             0             0              60
# 30948        Unmarried   Female             0             0              40
# 29811    Not-in-family   Female             0             0              50
# 18408          Husband     Male         10605             0              10
# 2879    Other-relative     Male             0             0              40
# 21575          Husband     Male             0             0              45
# 26396        Unmarried   Female             0             0              37
# 28644          Husband     Male         15024             0              40
# 15694        Own-child     Male          4416             0              40
# 23007          Husband     Male             0             0              40
# 2647     Not-in-family   Female          4101             0              50
# 19108        Own-child   Female             0             0              20
# 545               Wife   Female             0             0               8
# 14794          Husband     Male             0          1485              45
# 29400          Husband     Male             0             0              40
# 12808        Own-child   Female             0             0              40
# 22724        Own-child   Female             0             0              16
# 17729          Husband     Male             0             0              40
# 19705    Not-in-family     Male             0             0              48
# 32412          Husband     Male             0             0              40
# 27828        Unmarried   Female             0             0              40
# 31952             Wife   Female             0          1848              40
# 3407           Husband     Male             0             0              50
# 21190        Unmarried     Male             0             0              40
# 29563          Husband     Male             0             0              60
# 22977    Not-in-family     Male             0             0              40
# 16345        Unmarried   Female             0             0              40
# 13532             Wife   Female             0             0              45
# 19306        Own-child     Male             0             0              48
# ...                ...      ...           ...           ...             ...
# 8939     Not-in-family     Male             0             0              30
# 3760     Not-in-family   Female             0             0              40
# 3066     Not-in-family   Female             0             0              40
# 9539         Own-child     Male             0             0              30
# 23920          Husband     Male             0             0              40
# 21990          Husband     Male             0             0              40
# 30184          Husband     Male             0             0              40
# 513      Not-in-family     Male             0             0              45
# 20761    Not-in-family     Male             0             0              40
# 31391    Not-in-family     Male             0             0               3
# 31544    Not-in-family   Female             0             0              40
# 29538          Husband     Male             0             0              40
# 14155    Not-in-family     Male             0             0              65
# 14696    Not-in-family     Male             0             0              42
# 13397          Husband     Male             0             0              40
# 18502    Not-in-family   Female             0             0              38
# 997            Husband     Male          2580             0              40
# 18462          Husband     Male         99999             0              50
# 24508          Husband     Male             0          1902              50
# 19204    Not-in-family     Male             0             0              40
# 12503          Husband     Male             0             0              35
# 21561          Husband     Male             0             0              48
# 8723           Husband     Male          4064             0              45
# 1058           Husband     Male             0             0              47
# 27681    Not-in-family   Female             0             0              30
# 30772          Husband     Male             0             0              40
# 19781    Not-in-family   Female             0             0              35
# 21634        Own-child     Male             0             0              40
# 11391          Husband     Male             0             0              40
# 22201        Own-child   Female             0             0              40
#
#        native-country  salary
# 11358   United-States    >50K
# 10859   United-States    >50K
# 30948   United-States   <=50K
# 29811   United-States   <=50K
# 18408   United-States    >50K
# 2879    United-States   <=50K
# 21575   United-States   <=50K
# 26396   United-States   <=50K
# 28644   United-States    >50K
# 15694   United-States   <=50K
# 23007   United-States    >50K
# 2647    United-States   <=50K
# 19108   United-States   <=50K
# 545     United-States   <=50K
# 14794   United-States    >50K
# 29400               ?    >50K
# 12808   United-States    >50K
# 22724   United-States   <=50K
# 17729   United-States   <=50K
# 19705   United-States   <=50K
# 32412               ?   <=50K
# 27828   United-States   <=50K
# 31952   United-States    >50K
# 3407    United-States    >50K
# 21190   United-States    >50K
# 29563   United-States   <=50K
# 22977   United-States    >50K
# 16345          Mexico   <=50K
# 13532   United-States   <=50K
# 19306   United-States   <=50K
# ...               ...     ...
# 8939    United-States   <=50K
# 3760    United-States   <=50K
# 3066    United-States   <=50K
# 9539    United-States   <=50K
# 23920          Mexico   <=50K
# 21990          Mexico   <=50K
# 30184   United-States   <=50K
# 513     United-States   <=50K
# 20761   United-States   <=50K
# 31391   United-States   <=50K
# 31544   United-States   <=50K
# 29538   United-States   <=50K
# 14155   United-States   <=50K
# 14696   United-States   <=50K
# 13397   United-States   <=50K
# 18502   United-States   <=50K
# 997     United-States   <=50K
# 18462   United-States    >50K
# 24508   United-States   <=50K
# 19204   United-States   <=50K
# 12503   United-States    >50K
# 21561   United-States   <=50K
# 8723    United-States   <=50K
# 1058    United-States    >50K
# 27681   United-States   <=50K
# 30772               ?    >50K
# 19781   United-States   <=50K
# 21634   United-States   <=50K
# 11391   United-States   <=50K
# 22201   United-States   <=50K
#
# [100 rows x 11 columns]

# %% [markdown]
# ## Race vs Salary

# %%
# drop columns won't be useful in analysis and prediction
data_race = data.drop(['fnlwgt', 'education-num', 'education','age'], axis=1)

# %%
data_race.head()
# Out:
#            workclass       marital-status          occupation    relationship  \
# 0   Self-emp-not-inc   Married-civ-spouse     Exec-managerial         Husband
# 1            Private             Divorced   Handlers-cleaners   Not-in-family
# 2            Private   Married-civ-spouse   Handlers-cleaners         Husband
# 3            Private   Married-civ-spouse      Prof-specialty            Wife
# 4            Private   Married-civ-spouse     Exec-managerial            Wife
#
#      race      sex  capital-gain  capital-loss  hours-per-week  \
# 0   White     Male             0             0              13
# 1   White     Male             0             0              40
# 2   Black     Male             0             0              40
# 3   Black   Female             0             0              40
# 4   White   Female             0             0              40
#
#    native-country  salary
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3            Cuba   <=50K
# 4   United-States   <=50K

# %%
data_race.shape
# Out:
# (32560, 11)

# %% [markdown]
# ## Decreasing the sample size `n=100` for ease of use

# %%
data_race.sample(n=100, random_state=10)
# Out:
#                workclass       marital-status          occupation  \
# 11358            Private   Married-civ-spouse               Sales
# 10859            Private   Married-civ-spouse               Sales
# 30948            Private            Separated   Machine-op-inspct
# 29811       Self-emp-inc            Separated      Prof-specialty
# 18408                  ?   Married-civ-spouse                   ?
# 2879             Private        Never-married   Handlers-cleaners
# 21575            Private   Married-civ-spouse     Exec-managerial
# 26396            Private            Separated     Exec-managerial
# 28644            Private   Married-civ-spouse     Exec-managerial
# 15694        Without-pay        Never-married   Handlers-cleaners
# 23007   Self-emp-not-inc   Married-civ-spouse        Craft-repair
# 2647             Private        Never-married        Adm-clerical
# 19108            Private        Never-married       Other-service
# 545              Private   Married-civ-spouse       Other-service
# 14794            Private   Married-civ-spouse        Craft-repair
# 29400            Private   Married-civ-spouse               Sales
# 12808            Private   Married-civ-spouse       Other-service
# 22724            Private        Never-married        Adm-clerical
# 17729          State-gov   Married-civ-spouse        Tech-support
# 19705                  ?        Never-married                   ?
# 32412            Private   Married-civ-spouse   Machine-op-inspct
# 27828          Local-gov             Divorced      Prof-specialty
# 31952            Private   Married-civ-spouse     Exec-managerial
# 3407             Private   Married-civ-spouse               Sales
# 21190            Private            Separated     Exec-managerial
# 29563            Private   Married-civ-spouse               Sales
# 22977            Private            Separated      Prof-specialty
# 16345                  ?        Never-married                   ?
# 13532            Private   Married-civ-spouse      Prof-specialty
# 19306            Private        Never-married   Machine-op-inspct
# 31391    Not-in-family   White     Male             0             0
# 31544    Not-in-family   White   Female             0             0
# 29538          Husband   Black     Male             0             0
# 14155    Not-in-family   White     Male             0             0
# 14696    Not-in-family   White     Male             0             0
# 13397          Husband   White     Male             0             0
# 18502    Not-in-family   White   Female             0             0
# 997            Husband   White     Male          2580             0
# 18462          Husband   White     Male         99999             0
# 24508          Husband   White     Male             0          1902
# 19204    Not-in-family   Other     Male             0             0
# 12503          Husband   White     Male             0             0
# 21561          Husband   Black     Male             0             0
# 8723           Husband   White     Male          4064             0
# 1058           Husband   White     Male             0             0
# 27681    Not-in-family   White   Female             0             0
# 30772          Husband   White     Male             0             0
# 19781    Not-in-family   Black   Female             0             0
# 21634        Own-child   White     Male             0             0
# 11391          Husband   White     Male             0             0
# 22201        Own-child   Black   Female             0             0
#
#        hours-per-week  native-country  salary
# 11358              50   United-States    >50K
# 10859              60   United-States    >50K
# 30948              40   United-States   <=50K
# 29811              50   United-States   <=50K
# 18408              10   United-States    >50K
# 2879               40   United-States   <=50K
# 21575              45   United-States   <=50K
# 26396              37   United-States   <=50K
# 28644              40   United-States    >50K
# 15694              40   United-States   <=50K
# 23007              40   United-States    >50K
# 2647               50   United-States   <=50K
# 19108              20   United-States   <=50K
# 545                 8   United-States   <=50K
# 14794              45   United-States    >50K
# 29400              40               ?    >50K
# 12808              40   United-States    >50K
# 22724              16   United-States   <=50K
# 17729              40   United-States   <=50K
# 19705              48   United-States   <=50K
# 32412              40               ?   <=50K
# 27828              40   United-States   <=50K
# 31952              40   United-States    >50K
# 3407               50   United-States    >50K
# 21190              40   United-States    >50K
# 29563              60   United-States   <=50K
# 22977              40   United-States    >50K
# 16345              40          Mexico   <=50K
# 13532              45   United-States   <=50K
# 19306              48   United-States   <=50K
# ...               ...             ...     ...
# 8939               30   United-States   <=50K
# 3760               40   United-States   <=50K
# 3066               40   United-States   <=50K
# 9539               30   United-States   <=50K
# 23920              40          Mexico   <=50K
# 21990              40          Mexico   <=50K
# 30184              40   United-States   <=50K
# 513                45   United-States   <=50K
# 20761              40   United-States   <=50K
# 31391               3   United-States   <=50K
# 31544              40   United-States   <=50K
# 29538              40   United-States   <=50K
# 14155              65   United-States   <=50K
# 14696              42   United-States   <=50K
# 13397              40   United-States   <=50K
# 18502              38   United-States   <=50K
# 997                40   United-States   <=50K
# 18462              50   United-States    >50K
# 24508              50   United-States   <=50K
# 19204              40   United-States   <=50K
# 12503              35   United-States    >50K
# 21561              48   United-States   <=50K
# 8723               45   United-States   <=50K
# 1058               47   United-States    >50K
# 27681              30   United-States   <=50K
# 30772              40               ?    >50K
# 19781              35   United-States   <=50K
# 21634              40   United-States   <=50K
# 11391              40   United-States   <=50K
# 22201              40   United-States   <=50K
#
# [100 rows x 11 columns]

# %% [markdown]
# ## Native-Country vs Salary

# %%
# drop columns won't be useful in analysis and prediction
data_country = data.drop(['fnlwgt', 'education-num', 'education','race'], axis=1)

# %%
data_country

# %% [markdown]
# ## Decreasing the sample size `n=100` for ease of use

# %%
data_country.sample(n=100, random_state=10)
